# %%
# !wget https://vizwiz.cs.colorado.edu/VizWiz_final/images/train.zip
# Out:
# --2023-12-29 08:46:21--  https://vizwiz.cs.colorado.edu/VizWiz_final/images/train.zip
# Resolving vizwiz.cs.colorado.edu (vizwiz.cs.colorado.edu)... 198.59.7.50
# Connecting to vizwiz.cs.colorado.edu (vizwiz.cs.colorado.edu)|198.59.7.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11298421598 (11G) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>]  10.52G  7.14MB/s    in 26m 43s
#
# 2023-12-29 09:13:04 (6.72 MB/s) - ‘train.zip’ saved [11298421598/11298421598]

# %%
# !wget https://vizwiz.cs.colorado.edu/VizWiz_final/images/val.zip
# Out:
# --2023-12-29 09:13:05--  https://vizwiz.cs.colorado.edu/VizWiz_final/images/val.zip
# Resolving vizwiz.cs.colorado.edu (vizwiz.cs.colorado.edu)... 198.59.7.50
# Connecting to vizwiz.cs.colorado.edu (vizwiz.cs.colorado.edu)|198.59.7.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3488913457 (3.2G) [application/zip]
# Saving to: ‘val.zip’
#
# val.zip             100%[===================>]   3.25G  3.38MB/s    in 8m 28s
#
# 2023-12-29 09:21:33 (6.55 MB/s) - ‘val.zip’ saved [3488913457/3488913457]

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#    creating: train/
#   inflating: train/VizWiz_train_00013450.jpg
#   inflating: train/VizWiz_train_00001971.jpg
#   inflating: train/VizWiz_train_00003437.jpg
#   inflating: train/VizWiz_train_00000007.jpg
#   inflating: train/VizWiz_train_00018827.jpg
#   inflating: train/VizWiz_train_00018194.jpg
#   inflating: train/VizWiz_train_00013681.jpg
#   inflating: train/VizWiz_train_00021446.jpg
#   inflating: train/VizWiz_train_00022722.jpg
#   inflating: train/VizWiz_train_00013461.jpg
#   inflating: train/VizWiz_train_00019616.jpg
#   inflating: train/VizWiz_train_00018383.jpg
#   inflating: train/VizWiz_train_00011355.jpg
#   inflating: train/VizWiz_train_00015226.jpg
#   inflating: train/VizWiz_train_00013897.jpg
#   inflating: train/VizWiz_train_00006661.jpg
#   inflating: train/VizWiz_train_00001357.jpg
#   inflating: train/VizWiz_train_00014267.jpg
#   inflating: train/VizWiz_train_00014066.jpg
#   inflating: train/VizWiz_train_00007107.jpg
# ...

# %%
# !unzip val.zip
# Out:
# Archive:  val.zip
#    creating: val/
#   inflating: val/VizWiz_val_00004462.jpg
#   inflating: val/VizWiz_val_00001933.jpg
#   inflating: val/VizWiz_val_00005103.jpg
#   inflating: val/VizWiz_val_00003094.jpg
#   inflating: val/VizWiz_val_00004132.jpg
#   inflating: val/VizWiz_val_00001288.jpg
#   inflating: val/VizWiz_val_00003226.jpg
#   inflating: val/VizWiz_val_00002319.jpg
#   inflating: val/VizWiz_val_00004068.jpg
#   inflating: val/VizWiz_val_00002975.jpg
#   inflating: val/VizWiz_val_00000973.jpg
#   inflating: val/VizWiz_val_00002931.jpg
#   inflating: val/VizWiz_val_00000213.jpg
#   inflating: val/VizWiz_val_00001771.jpg
#   inflating: val/VizWiz_val_00000617.jpg
#   inflating: val/VizWiz_val_00002095.jpg
#   inflating: val/VizWiz_val_00007503.jpg
#   inflating: val/VizWiz_val_00004027.jpg
#   inflating: val/VizWiz_val_00004952.jpg
#   inflating: val/VizWiz_val_00004873.jpg
#   inflating: val/VizWiz_val_00004468.jpg
#   inflating: val/VizWiz_val_00005128.jpg
# ...

# %%
import json

with open('../annotations/train.json') as f:
  train_annotations = json.load(f)

with open('../annotations/val.json') as f:
  val_annotations = json.load(f)

# %%
from PIL import Image

img = Image.open("../../train/VizWiz_train_00000009.jpg")
img.show()
print(train_annotations['annotations'][45]['caption'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=484x648>
# A silver cover drain in the middle of a white floor.

# %%
import pandas as pd

# %%
val_annotations
# Out:
# {'info': {'description': 'This dataset contains crowdsourced captions of images from VizWiz datasets. This file contains the val partition.',
#   'license': {'url': 'https://creativecommons.org/licenses/by/4.0/',
#    'name': 'Attribution 4.0 International (CC BY 4.0)'},
#   'url': 'https://vizwiz.org',
#   'version': 'VizWiz-Captions 1.0',
#   'year': 2019,
#   'contributor': 'VizWiz-Captions Consortium',
#   'date_created': '2019-12-23'},
#  'images': [{'file_name': 'VizWiz_val_00000000.jpg',
#    'vizwiz_url': 'https://ivc.ischool.utexas.edu/VizWiz_visualization_img/VizWiz_val_00000000.jpg',
#    'id': 23431,
#    'text_detected': True},
#   {'file_name': 'VizWiz_val_00000001.jpg',
#    'vizwiz_url': 'https://ivc.ischool.utexas.edu/VizWiz_visualization_img/VizWiz_val_00000001.jpg',
#    'id': 23432,
#    'text_detected': True},
#   {'file_name': 'VizWiz_val_00000002.jpg',
#    'vizwiz_url': 'https://ivc.ischool.utexas.edu/VizWiz_visualization_img/VizWiz_val_00000002.jpg',
# ...

# %%
train_captions = []
train_image_id = []
val_captions = []
val_image_id = []

for caption_data in train_annotations["annotations"]:
  train_captions.append(caption_data["caption"])
  train_image_id.append(caption_data["image_id"])

for caption_data in val_annotations["annotations"]:
  val_captions.append(caption_data["caption"])
  val_image_id.append(caption_data["image_id"])

# %%
train_image_file = [train_annotations['images'][img]['file_name'] for img in train_image_id]
val_image_file = [val_annotations['images'][img - 23431]['file_name'] for img in val_image_id]

# %%
train_data = pd.DataFrame({'image_file': train_image_file, 'captions': train_captions})
test_data = pd.DataFrame({'image_file': val_image_file, 'captions': val_captions})

# %%
train_data
# Out:
#                        image_file  \
# 0       VizWiz_train_00000000.jpg
# 1       VizWiz_train_00000000.jpg
# 2       VizWiz_train_00000000.jpg
# 3       VizWiz_train_00000000.jpg
# 4       VizWiz_train_00000000.jpg
# ...                           ...
# 117150  VizWiz_train_00023430.jpg
# 117151  VizWiz_train_00023430.jpg
# 117152  VizWiz_train_00023430.jpg
# 117153  VizWiz_train_00023430.jpg
# 117154  VizWiz_train_00023430.jpg
#
#                                                  captions
# 0       ITS IS A BASIL LEAVES CONTAINER ITS CONTAINS T...
# 1       A green and white plastic condiment bottle con...
# 2       Quality issues are too severe to recognize vis...
# 3       A bottle of spices in a plastic container layi...
# 4           some basil leaves in a container on a counter
# ...                                                   ...
# 117150  The back of a plastic card such as a credit ca...
# 117151  A card is seen with a scratch strip to reveal ...
# ...

# %%
contractions = [
    "aren't",
    "there's",
    "can't",
    "they'd",
    "couldn't",
    "they'll",
    "didn't",
    "they're",
    "doesn't",
    "they've",
    "don't",
    "we'd",
    "we're",
    "hasn't",
    "we've",
    "haven't",
    "weren't",
    "he'd",
    "what'll",
    "he'll",
    "what're",
    "he's",
    "what's",
    "I'd",
    "what've",
    "I'll",
    "where's",
    "I'm",
    "who'd",
    "I've",
    "who'll",
    "isn't",
    "who're",
    "let's",
    "who's",
    "mightn't",
    "won't",
    "mustn't",
    "wouldn't",
    "she'd",
    "you'd",
    "she'll",
    "you'll",
    "she's",
    "you're",
    "shouldn't",
    "you've"
]

# %%
expansion = [
    "are not",
    "there is",
    "can not",
    "they had",
    "could not",
    "they will",
    "did not",
    "they are",
    "does not",
    "they have",
    "do not",
    "we had",
    "we are",
    "has not",
    "we have",
    "have not",
    "were not",
    "he had",
    "what will",
    "he will",
    "what are",
    "he is",
    "what is",
    "I had",
    "what have",
    "I will",
    "where is",
    "I am",
    "who had",
    "I have",
    "who will",
    "is not",
    "who are",
    "let us",
    "who is",
    "might not",
    "will not",
    "must not",
    "would not",
    "she had",
    "you had",
    "she will",
    "you will",
    "she is",
    "you are",
    "should not",
    "you have"
]

# %%
len(contractions) == len(expansion)
# Out:
# True

# %%
def count_contractions(data, contractions):
  num_of_contractions = 0
  for cap in data.captions.values:
    for cont in contractions:
      if cont in cap:
        num_of_contractions += 1

  return num_of_contractions

print(count_contractions(train_data, contractions))
# Out:
# 255

# %%
def remove_contractions(data, contractions, expansion):
  for cap_idx in range(len(data.captions.values)):
    for cont_idx in range(len(contractions)):
      if contractions[cont_idx] in data.captions[cap_idx]:
        data.captions[cap_idx] = data.captions[cap_idx].replace(contractions[cont_idx], expansion[cont_idx])

  return data

# %%
train_data = remove_contractions(train_data, contractions, expansion)
count_contractions(train_data, contractions)
# Out:
# 0

# %%
test_data = remove_contractions(test_data, contractions, expansion)
count_contractions(test_data, contractions)
# Out:
# 0

# %%
import string
import inflect

# %%
def remove_number(org_str):
  engine = inflect.engine()

  for word in org_str.split():
    if not word.isalpha():
      org_str = org_str.replace(word, engine.number_to_words(word))

  return org_str

def remove_punctuation(org_str):
  org_str = org_str.replace("-", " ")
  org_str = org_str.translate(str.maketrans('', '', string.punctuation))
  return org_str

# %%
remove_punctuation("!.this?\'")
# Out:
# 'this'

# %%
remove_punctuation(remove_number("1233"))
# Out:
# 'one thousand two hundred and thirty three'

# %%
for cap_idx in range(len(train_data.captions)):
  train_data.captions[cap_idx] = remove_punctuation(remove_number(train_data.captions[cap_idx])).lower()

# %%
for cap_idx in range(len(test_data.captions)):
  test_data.captions[cap_idx] = remove_punctuation(remove_number(test_data.captions[cap_idx])).lower()

# %%
vocabulary = []
for txt in train_data.captions:
  vocabulary.extend(txt.split())

vocabulary = set(vocabulary)
print("Train Vocab Size: ", len(vocabulary))
# Out:
# Train Vocab Size:  15639

# %%
for idx in range(len(train_data.image_file)):
  train_data.image_file[idx] = "../train/" + train_data.image_file[idx]

for idx in range(len(test_data.image_file)):
  test_data.image_file[idx] = "../val/" + test_data.image_file[idx]

# %%
train_data.to_csv('train.csv', index=False)
test_data.to_csv('test.csv', index=False)

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
from PIL import Image

# %%
img_sizes = []

for img_file in train_data['image_file'][::5]:
  img = Image.open(img_file)
  h, w = img.size

  img_sizes.append((h, w))

# %%
unique = list(set(img_sizes))
len(unique) # num of unique sizes
# Out:
# 122

# %%
import matplotlib.pyplot as plt

# %%
x = [item[0] for item in img_sizes]
y = [item[1] for item in img_sizes]

# %%
plt.scatter(x, y, label='Data Points')
plt.xlabel('Height')
plt.ylabel('Width')
plt.title('Height vs Width Graph')

# Show the plot
plt.show()

# %%
min(img_sizes)
# Out:
# (10, 13)

# %%
print(sum([i[0] for i in img_sizes])/len(img_sizes)) # avg width
print(sum([i[1] for i in img_sizes])/len(img_sizes)) # avg height
# Out:
# 1098.7283940079383
# 1355.2681490333318

# %%
import numpy as np

quartiles_x = np.percentile(x, [25, 50, 75])
quartiles_y = np.percentile(y, [25, 50, 75])

# %%
quartiles_x
# Out:
# array([ 968.,  968., 1224.])

# %%
quartiles_y
# Out:
# array([1296., 1296., 1632.])

# %%
len([item for item in img_sizes if item == (968, 1296)])
# Out:
# 7660

# %%
import torch
import torchvision

# %%
transform = torchvision.transforms.Compose([
     torchvision.transforms.Resize((300, 300)),
     torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

# %%
transform(Image.open(train_data.image_file[0])).shape
# Out:
# torch.Size([3, 300, 300])

# %%
class VizWiz(torch.utils.data.Dataset):
  def __init__(self, img_paths, captions, transforms, tokenizer):
      self.img_paths = img_paths
      self.captions = tokenizer(captions, padding = True, return_tensors = 'pt')['input_ids']
      self.transforms = transforms

  def __len__(self):
      return len(self.captions)

  def __getitem__(self, index):
      image = self.img_paths[index]
      image = Image.open(image)
      image = self.transforms(image)

      targets = self.captions[index]
      return image, targets

# %%
VizWiz_train = VizWiz(train_data.image_file.to_list(), train_data.captions.to_list(), transform, tokenizer)

# %%
VizWiz_test = VizWiz(test_data.image_file.to_list(), test_data.captions.to_list(), transform, tokenizer)

# %%
train_dataloader = torch.utils.data.DataLoader(VizWiz_train, batch_size=64, shuffle=True, drop_last=True)
test_dataloader = torch.utils.data.DataLoader(VizWiz_test, batch_size=64, shuffle=True, drop_last=True)

# %%
len(train_dataloader)
# Out:
# 1830

# %%
import sys
sys.path.append('../')

# %%
from vt_captioning.vt_resnet import vt_resnet50
from transformer_code.vt_captioning import VTCaptionModel

# %%
feature_extractor = vt_resnet50(
            pretrained=True,
            freeze='full_freeze',
            tokens=16,
            token_channels=128,
            input_dim=1024,
            vt_channels=2048,
            transformer_enc_layers=2,
            transformer_heads=8,
            transformer_fc_dim=2048,
            image_channels=3,
        )
# Out:
# 3

# %%
VOCAB_SIZE = len(tokenizer)

# %%
model = VTCaptionModel(feature_extractor, num_layers = 4, d_model = 512, num_heads = 8, dff = 2048, row_size = 1, col_size = 1, target_vocab_size = VOCAB_SIZE, max_pos_encoding=VOCAB_SIZE, rate=0.2)

# %%
from transformer_code.mha import create_look_ahead_mask, create_padding_mask

def create_masks_decoder(tar):
    look_ahead_mask = create_look_ahead_mask(tar.size(1))
    dec_target_padding_mask = create_padding_mask(tar)

    combined_mask = torch.max(dec_target_padding_mask.unsqueeze(1), look_ahead_mask)
    return combined_mask

# %%
import time

# %%
import torch.nn.functional as F

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def train_step(img_tensor, tar, transformer, optimizer, train_loss, train_accuracy):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    dec_mask = create_masks_decoder(tar_inp)

    optimizer.zero_grad()
    predictions, _ = transformer(img_tensor, tar_inp, True, dec_mask)
    loss = F.cross_entropy(tar_real, predictions)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    train_accuracy += torch.sum(torch.argmax(predictions, dim=-1) == tar_real).item() / tar_real.size(1)

    return train_loss, train_accuracy

# %%
def evaluate(model, val_loader):
    model.eval()
    val_loss = 0.0
    val_accuracy = 0.0

    with torch.no_grad():
        for batch_idx, (img_tensor, tar) in enumerate(val_loader):
            img_tensor = img_tensor.to(device)  # Move tensors to GPU if available
            tar = tar.to(device)

            tar_inp = tar[:, :-1]
            tar_real = tar[:, 1:]
            dec_mask = create_masks_decoder(tar_inp)

            predictions, _ = model(img_tensor, tar_inp, False, dec_mask)
            loss = F.cross_entropy(tar_real, predictions)

            val_loss += loss.item()
            val_accuracy += torch.sum(torch.argmax(predictions, dim=-1) == tar_real).item() / tar_real.size(1)

    return val_loss / len(val_loader), 100.0 * val_accuracy / len(val_loader)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5, betas=(0.9, 0.98), eps=1e-9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.8)

# %%
num_epochs = 60


for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_accuracy = 0.0

    for batch_idx, (img_tensor, tar) in enumerate(train_dataloader):
        optimizer.zero_grad()
        img_tensor = img_tensor.to(device)  # Move tensors to GPU if available

        tar = tar.to(device)

        train_loss, train_accuracy = train_step(img_tensor, tar, model, optimizer, train_loss, train_accuracy)

    scheduler.step()  # Adjust learning rate
    test_loss, test_accuracy = evaluate(model, test_dataloader)


    print(f"Epoch [{epoch + 1}/{num_epochs}] "
          f"Train Loss: {train_loss / len(train_dataloader):.4f} "
          f"Train Accuracy: {100.0 * train_accuracy / len(train_dataloader):.2f}% "
          f"Test Loss: {test_loss} "
          f"Test Accuracy: {test_accuracy}%"
          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 num_epochs = 60
#       4 for epoch in range(num_epochs):
# ----> 5     model.train()
#       6     train_loss = 0.0
#       7     train_accuracy = 0.0
#
# NameError: name 'model' is not defined
